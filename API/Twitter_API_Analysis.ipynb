# %%
#twitter_consumer_key = 'dkKuVj587YzV3xY3nNUPGvJR9'
#twitter_consumer_secret = 'qSakB6L7b7tDouDT4DBXDoHbkdNZVeB0KglFzd9LKQQSbZZKwS'
#twitter_access_token = '263850578-tNyRc0T1W9ivUlfomAmiDeNfWvVUOwd8liwaS6Fv'
#twitter_access_secret = '2dolG6luSuxkXL3T3UNDKURFcA4ZElnQJmJTrr4vZzMX3'

#twitter_api = twitter.Api(consumer_key=twitter_consumer_key, consumer_secret=twitter_consumer_secret, access_token_key=twitter_access_token, access_token_secret=twitter_access_secret)

# %%
import requests
from config import BEARER_TOKEN

q= "AD"
url = f'https://api.twitter.com/2/tweets/search/recent?query={q}&tweet.fields=author_id,created_at,entities,geo,in_reply_to_user_id,lang,possibly_sensitive,referenced_tweets,source'

header = {
    "Authorization": BEARER_TOKEN
}

r = requests.get(
    url,
    # params=parameters 
    headers=header
    ).json()
r
# tweet_id = r['da
r = requests.get(url, headers=header).json()
r
# Out:
# {'data': [{'entities': {'mentions': [{'start': 3,
#       'end': 9,
#       'username': '13yjn',
#       'id': '1410842199483240448'}],
#     'urls': [{'start': 44,
#       'end': 67,
#       'url': 'https://t.co/rmmrpxOnTb',
#       'expanded_url': 'https://twitter.com/13yjn/status/1451887800341569539/photo/1',
#       'display_url': 'pic.twitter.com/rmmrpxOnTb'}]},
#    'id': '1451936055184162823',
#    'lang': 'en',
#    'source': 'Twitter for Android',
#    'possibly_sensitive': False,
#    'created_at': '2021-10-23T15:38:25.000Z',
#    'text': 'RT @13yjn: I SAW THE HUGEST TCCFOE AD 🧍🏻\u200d♀️ https://t.co/rmmrpxOnTb',
#    'author_id': '1417834318169141252',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1451887800341569539'}]},
#   {'entities': {'hashtags': [{'start': 82, 'end': 94, 'tag': 'KarwaChauth'}],
#     'mentions': [{'start': 3,
#       'end': 14,
#       'username': 'ShefVaidya',
#       'id': '1934388686'}]},
#    'id': '1451936054500417540',
#    'lang': 'en',
#    'source': 'Twitter Web App',
#    'possibly_sensitive': False,
#    'created_at': '2021-10-23T15:38:25.000Z',
#    'text': 'RT @ShefVaidya: Saw a TV ad for a face bleach where two lesbian women are keeping #KarwaChauth. So when Hindu women voluntarily observe the…',
#    'author_id': '1209422765339500544',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1451877980666425354'}]},
#   {'entities': {'mentions': [{'start': 0,
#       'end': 16,
#       'username': 'RelatableJulian',
#       'id': '754367309058191360'}]},
#    'id': '1451936054026588162',
#    'lang': 'en',
#    'source': 'Twitter for iPhone',
#    'in_reply_to_user_id': '754367309058191360',
#    'possibly_sensitive': False,
#    'created_at': '2021-10-23T15:38:25.000Z',
#    'text': '@RelatableJulian Buddy is slappn AD around with them facts 😂',
#    'author_id': '1171875660249358336',
#    'referenced_tweets': [{'type': 'replied_to', 'id': '1451934398178234368'}]},
#   {'entities': {'mentions': [{'start': 3,
#       'end': 18,
#       'username': 'archaeologyart',
#       'id': '765618069062422528'}],
#     'annotations': [{'start': 55,
#       'end': 65,
#       'probability': 0.2462,
#       'type': 'Place',
#       'normalized_text': 'Roman Egypt'},
#      {'start': 79,
#       'end': 111,
#       'probability': 0.2111,
#       'type': 'Organization',
#       'normalized_text': 'Pushkin State Museum of Fine Arts'},
#      {'start': 114,
#       'end': 119,
#       'probability': 0.6167,
#       'type': 'Place',
#       'normalized_text': 'Moscow'}]},
#    'id': '1451936052952899589',
#    'lang': 'en',
#    'source': 'Twitter Web App',
#    'possibly_sensitive': False,
#    'created_at': '2021-10-23T15:38:25.000Z',
#    'text': 'RT @archaeologyart: Funeral shroud from 2nd Century AD Roman Egypt. Now in the Pushkin State Museum of Fine Arts, Moscow.  Read more: https…',
#    'author_id': '985088500457529344',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1451896238664822792'}]},
#   {'entities': {'mentions': [{'start': 3,
#       'end': 16,
#       'username': 'Joshuazilkey',
#       'id': '114824502'},
#      {'start': 80, 'end': 90, 'username': 'riotgames', 'id': '20523846'}]},
#    'id': '1451936052747202561',
#    'lang': 'en',
#    'source': 'Twitter for Android',
#    'possibly_sensitive': False,
#    'created_at': '2021-10-23T15:38:25.000Z',
#    'text': 'RT @Joshuazilkey: LMAO I was just about to tweet how I love the excitement when @riotgames plays Silver scrapes before game 5 and they run…',
#    'author_id': '3104125129',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1451935478047907850'}]},
#   {'entities': {'hashtags': [{'start': 42, 'end': 48, 'tag': 'Roman'}],
#     'mentions': [{'start': 3,
#       'end': 12,
#       'username': 'DrJEBall',
#       'id': '942518599171928064'}],
#     'annotations': [{'start': 120,
#       'end': 127,
#       'probability': 0.4464,
#       'type': 'Place',
#       'normalized_text': 'Vesuvius'},
#      {'start': 130,
#       'end': 134,
#       'probability': 0.5756,
#       'type': 'Place',
#       'normalized_text': 'Italy'}]},
#    'id': '1451936050847305738',
#    'lang': 'en',
#    'source': 'Twitter for Android',
#    'possibly_sensitive': False,
#    'created_at': '2021-10-23T15:38:24.000Z',
#    'text': 'RT @DrJEBall: A colourful &amp; beautiful #Roman millefiori glass bowl, dated late C1stBC-early C1st AD, in the area around Vesuvius (Italy). J…',
#    'author_id': '411223229',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1451497810491281409'}]},
#   {'entities': {'mentions': [{'start': 3,
#       'end': 18,
#       'username': 'hansvantelling',
#       'id': '561171009'}]},
#    'id': '1451936050151149568',
#    'lang': 'nl',
#    'source': 'Twitter for iPhone',
#    'possibly_sensitive': False,
#    'created_at': '2021-10-23T15:38:24.000Z',
#    'text': 'RT @hansvantelling: Ah. De man die altijd minimaal vier keer te hoog uitkomt met zijn voorspellingen. We gaan niet meer in lockdown. Lockdo…',
#    'author_id': '305151421',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1451853527991701505'}]},
#   {'entities': {'urls': [{'start': 107,
#       'end': 130,
#       'url': 'https://t.co/uQHAArhKVO',
#       'expanded_url': 'https://ad-flyer-static.smartnews.com/app/lp20211019.html',
#       'display_url': 'ad-flyer-static.smartnews.com/app/lp20211019…',
#       'images': [{'url': 'https://pbs.twimg.com/news_img/1450280664046075907/9esBCKrB?format=jpg&name=orig',
#         'width': 160,
#         'height': 160},
#        {'url': 'https://pbs.twimg.com/news_img/1450280664046075907/9esBCKrB?format=jpg&name=150x150',
#         'width': 150,
#         'height': 150}],
#       'status': 200,
#       'title': 'ヘパリーゼ：【清涼飲料水・栄養補助食品】\u3000[ゼリア新薬]',
#       'description': 'ゼリア新薬「ヘパリーゼ」【清涼飲料水・栄養補助食品】紹介サイトです。製品情報やCM情報など。',
#       'unwound_url': 'https://www.hepa-w.jp/?utm_source=smartnews&utm_medium=text&utm_content=snsshare&utm_campaign=sampling2'}]},
#    'id': '1451936049341427712',
#    'lang': 'ja',
#    'source': 'Twitter Web App',
#    'possibly_sensitive': False,
#    'created_at': '2021-10-23T15:38:24.000Z',
#    'text': '【スマートニュースで抽選中！】\nお家でも！ヘパリーゼWチャージ！\n抽選でヘパリーゼWを10万名様にプレゼント！\n期間は10月19日（火）から10月25日（月）となります。\n\nこの機会に、「家ヘパW」始めませんか？ https://t.co/uQHAArhKVO',
#    'author_id': '986602403498622976'},
#   {'entities': {'hashtags': [{'start': 16, 'end': 20, 'tag': 'TXT'},
#      {'start': 21, 'end': 28, 'tag': 'Soobin'}],
#     'mentions': [{'start': 3,
#       'end': 13,
#       'username': 'kstargift',
#       'id': '1199932756471382017'}],
#     'urls': [{'start': 95,
#       'end': 118,
#       'url': 'https://t.co/sO89P2JP8a',
#       'expanded_url': 'http://bit.ly/3aKhjje',
#       'display_url': 'bit.ly/3aKhjje',
#       'images': [{'url': 'https://pbs.twimg.com/news_img/1449419895272181765/-xgEe3JV?format=jpg&name=orig',
#         'width': 500,
#         'height': 500},
#        {'url': 'https://pbs.twimg.com/news_img/1449419895272181765/-xgEe3JV?format=jpg&name=150x150',
#         'width': 150,
#         'height': 150}],
#       'status': 200,
#       'title': "[SARANG] TXT's Soobin BIRTHDAY PROJECT",
#       'description': 'Join now K-Supporter Projects',
#       'unwound_url': 'https://kshoplive.com/product/sarang-txts-soobin-birthday-project/1144/?cate_no=223&display_group=1'}],
#     'annotations': [{'start': 80,
#       'end': 84,
#       'probability': 0.8825,
#       'type': 'Place',
#       'normalized_text': 'SEOUL'}]},
#    'id': '1451936046040584195',
#    'lang': 'en',
#    'source': 'Twitter for Android',
#    'possibly_sensitive': False,
#    'created_at': '2021-10-23T15:38:23.000Z',
#    'text': "RT @kstargift: 🎂#TXT #Soobin's BIRTHDAY PROJECT\nLET'S CROWDFUND A SUBWAY AD IN SEOUL FOR HIM!\n▶https://t.co/sO89P2JP8a\n\nUntil 2021.11.15 23…",
#    'author_id': '1162748930129424384',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1451820692689719298'}]},
#   {'entities': {'mentions': [{'start': 3,
#       'end': 11,
#       'username': 'PS5only',
#       'id': '2188714462'}],
#     'annotations': [{'start': 13,
#       'end': 23,
#       'probability': 0.6865,
#       'type': 'Product',
#       'normalized_text': '3ds Max 3D'}]},
#    'id': '1451936045663236101',
#    'lang': 'en',
#    'source': 'Twitter Web App',
#    'possibly_sensitive': False,
#    'created_at': '2021-10-23T15:38:23.000Z',
#    'text': 'RT @PS5only: 3ds Max\n\n3D modelling and rendering software for design visualisation, games and animation.\n\nDownload free trial\n\nAutodesk htt…',
#    'author_id': '1163603582291255296',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1451935695983955970'}]}],
#  'meta': {'newest_id': '1451936055184162823',
#   'oldest_id': '1451936045663236101',
#   'result_count': 10,
#   'next_token': 'b26v89c19zqg8o3fpdv67ypqhpga61khcexa8n3wqhf99'}}

# %%
# Out:
# Bearer AAAAAAAAAAAAAAAAAAAAAOVNUwEAAAAAnZ86fwMdjkpEr9hrXms02cfAti0%3DgY3VU9RK4Jp0T92CdhHkLi4qKB75olRsLclZbDXZkHkJwZ3p17
