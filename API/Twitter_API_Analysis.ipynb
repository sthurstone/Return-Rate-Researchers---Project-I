# %% [markdown]
# Twitter Anaylsis

# %%
import requests
import json
import pandas as pd
from pandas.io.json import json_normalize 
import time
import numpy as np
from config import BEARER_TOKEN

q= "AD"
url = f'https://api.twitter.com/2/tweets/search/recent?max_results=10&query={q}&tweet.fields=author_id,created_at,entities,geo,lang,possibly_sensitive,public_metrics,source'
#referenced_tweets,in_reply_to_user_id
header = {
    "Authorization": BEARER_TOKEN
}

#r = requests.get(
   # url,
    # params=parameters 
   # headers=header
   # ).json()
#r

# tweet_id = r['da
r = requests.get(url, headers=header).json()
r
# Out:
# {'data': [{'entities': {'annotations': [{'start': 99,
#       'end': 112,
#       'probability': 0.5947,
#       'type': 'Organization',
#       'normalized_text': 'News Consumers'}],
#     'hashtags': [{'start': 56, 'end': 66, 'tag': 'Christmas'}],
#     'mentions': [{'start': 3,
#       'end': 19,
#       'username': 'goodbuysalltime',
#       'id': '117271814'}]},
#    'public_metrics': {'retweet_count': 9,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'created_at': '2021-10-26T00:42:56.000Z',
#    'possibly_sensitive': False,
#    'lang': 'en',
#    'author_id': '2870146250',
#    'text': "RT @goodbuysalltime: 🎅It's Beginning to look a Lot like #Christmas 🎄\nIf you've been watching the News Consumers are being advised to #ShopE…",
#    'id': '1452797863126175750',
#    'source': 'Twitter Web App'},
#   {'public_metrics': {'retweet_count': 778,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'created_at': '2021-10-26T00:42:56.000Z',
#    'possibly_sensitive': False,
#    'lang': 'en',
#    'author_id': '1262862854769631232',
#    'text': "RT @jakeupdateteam: [DUCK AD TUTORIAL] \n\nLet's win a SUBWAY AD for #JAKE! 🐶🧡\n\nGoal: 3,000,000 votes! \n\nDownload links: \n🔗https://t.co/caka7…",
#    'entities': {'hashtags': [{'start': 67, 'end': 72, 'tag': 'JAKE'}],
#     'mentions': [{'start': 3,
#       'end': 18,
#       'username': 'jakeupdateteam',
#       'id': '1283273218439229441'}]},
#    'id': '1452797863054827525',
#    'source': 'Twitter for Android'},
#   {'entities': {'annotations': [{'start': 13,
#       'end': 20,
#       'probability': 0.937,
#       'type': 'Organization',
#       'normalized_text': 'Facebook'}],
#     'mentions': [{'start': 3,
#       'end': 11,
#       'username': 'Reuters',
#       'id': '1652541'}],
#     'urls': [{'start': 81,
#       'end': 104,
#       'url': 'https://t.co/D2XBJd1xpO',
#       'expanded_url': 'http://reut.rs/3CkpAqs',
#       'display_url': 'reut.rs/3CkpAqs',
#       'images': [{'url': 'https://pbs.twimg.com/news_img/1452797185964318720/zrnC03HD?format=jpg&name=orig',
#         'width': 1200,
#         'height': 628},
#        {'url': 'https://pbs.twimg.com/news_img/1452797185964318720/zrnC03HD?format=jpg&name=150x150',
#         'width': 150,
#         'height': 150}],
#       'status': 200,
#       'title': 'Facebook invests billions in metaverse efforts as ad business slows',
#       'description': 'Facebook Inc said on Monday it will start publishing the financial results of its augmented and virtual reality labs as a separate unit, where it is investing billions in its ambitions to build the "metaverse" and as it reported that its main advertising business faces "significant uncertainty."',
#       'unwound_url': 'https://www.reuters.com/technology/facebook-revenue-misses-estimates-apples-privacy-rules-bite-2021-10-25/?taid=61774e610fbc4500016c9dc0&utm_campaign=trueAnthem:+Trending+Content&utm_medium=trueAnthem&utm_source=twitter'},
#      {'start': 105,
#       'end': 128,
#       'url': 'https://t.co/wBsnFchX9B',
#       'expanded_url': 'https://twitter.com/Reuters/status/1452797184169086980/photo/1',
#       'display_url': 'pic.twitter.com/wBsnFchX9B'}]},
#    'public_metrics': {'retweet_count': 7,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'created_at': '2021-10-26T00:42:56.000Z',
#    'possibly_sensitive': False,
#    'lang': 'en',
#    'author_id': '734129690',
#    'text': 'RT @Reuters: Facebook invests billions in metaverse efforts as ad business slows https://t.co/D2XBJd1xpO https://t.co/wBsnFchX9B',
#    'id': '1452797860156637187',
#    'source': 'Twitter for iPad'},
#   {'entities': {'annotations': [{'start': 18,
#       'end': 35,
#       'probability': 0.3564,
#       'type': 'Organization',
#       'normalized_text': 'NY Times Square ad'},
#      {'start': 42,
#       'end': 45,
#       'probability': 0.8013,
#       'type': 'Person',
#       'normalized_text': 'ケイくん'}],
#     'mentions': [{'start': 3,
#       'end': 15,
#       'username': 'K_ILAND2020',
#       'id': '1280648216845803521'},
#      {'start': 84,
#       'end': 97,
#       'username': 'k_fluorite19',
#       'id': '1300576927648854016'}]},
#    'public_metrics': {'retweet_count': 41,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'created_at': '2021-10-26T00:42:55.000Z',
#    'possibly_sensitive': False,
#    'lang': 'ja',
#    'author_id': '1177489707099246593',
#    'text': 'RT @K_ILAND2020: 【NY Times Square ad】\n\nNYのケイくんも本日最終日です🗽👏\n素敵な作品をNYへ届けることができて\n嬉しいですね✨\n@k_fluorite19 様ありがとうございました😊🙏\n\nデビューする日が待ち遠しいです🌙\n\n#HYBEJP…',
#    'id': '1452797858269253641',
#    'source': 'Twitter for Android'},
#   {'public_metrics': {'retweet_count': 964,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'created_at': '2021-10-26T00:42:55.000Z',
#    'possibly_sensitive': False,
#    'lang': 'en',
#    'author_id': '2785265579',
#    'text': 'RT @100trillionUSD: Dutch government is lying through their teeth to force vaccination without consent: denying natural immunity, and sayin…',
#    'id': '1452797857904402442',
#    'source': 'Twitter for iPhone',
#    'entities': {'mentions': [{'start': 3,
#       'end': 18,
#       'username': '100trillionUSD',
#       'id': '918804624303382528'}]}},
#   {'public_metrics': {'retweet_count': 23,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'created_at': '2021-10-26T00:42:55.000Z',
#    'possibly_sensitive': False,
#    'lang': 'es',
#    'author_id': '1393169650389815297',
#    'text': 'RT @AquilianoL: @Mippcivzla Por el regreso a clases! 🙌✏️📒🧷\n#DigamosPresente\n@LCL23_1987 @LucenaCarmela @auritalucena @GorkiLucena @Elgrinc3…',
#    'entities': {'hashtags': [{'start': 59,
#       'end': 75,
#       'tag': 'DigamosPresente'}],
#     'mentions': [{'start': 3,
#       'end': 14,
#       'username': 'AquilianoL',
#       'id': '1379485239425257480'},
#      {'start': 16,
#       'end': 27,
#       'username': 'Mippcivzla',
#       'id': '839299289792774144'},
#      {'start': 76, 'end': 87, 'username': 'LCL23_1987', 'id': '267490254'},
#      {'start': 88,
#       'end': 102,
#       'username': 'LucenaCarmela',
#       'id': '1379574794358755328'},
#      {'start': 103,
#       'end': 116,
#       'username': 'auritalucena',
#       'id': '1390263017330429954'},
#      {'start': 117,
#       'end': 129,
#       'username': 'GorkiLucena',
#       'id': '1379748781416198145'}]},
#    'id': '1452797856830607362',
#    'source': 'Twitter for Android'},
#   {'public_metrics': {'retweet_count': 1,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'created_at': '2021-10-26T00:42:55.000Z',
#    'possibly_sensitive': False,
#    'lang': 'tr',
#    'author_id': '1238191063573159937',
#    'text': 'RT @McDrFn: Code 1KAZAMA #Ad https://t.co/pOJVuBu6PU',
#    'entities': {'hashtags': [{'start': 25, 'end': 28, 'tag': 'Ad'}],
#     'mentions': [{'start': 3,
#       'end': 10,
#       'username': 'McDrFn',
#       'id': '1449973818865373184'}],
#     'urls': [{'start': 29,
#       'end': 52,
#       'url': 'https://t.co/pOJVuBu6PU',
#       'expanded_url': 'https://twitter.com/McDrFn/status/1452797542350180361/photo/1',
#       'display_url': 'pic.twitter.com/pOJVuBu6PU'}]},
#    'id': '1452797856088199170',
#    'source': 'Twitter for Android'},
#   {'public_metrics': {'retweet_count': 579,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'created_at': '2021-10-26T00:42:54.000Z',
#    'possibly_sensitive': False,
#    'lang': 'en',
#    'author_id': '1285971193766371328',
#    'text': 'RT @PSHCITE: Since you’ll need to purchase gold coins to vote for #JAKE on whosfan, I’ll be proposing another donation drive for his birthd…',
#    'entities': {'hashtags': [{'start': 66, 'end': 71, 'tag': 'JAKE'}],
#     'mentions': [{'start': 3,
#       'end': 11,
#       'username': 'PSHCITE',
#       'id': '1323670537403392001'}]},
#    'id': '1452797853420572677',
#    'source': 'Twitter for Android'},
#   {'entities': {'annotations': [{'start': 41,
#       'end': 52,
#       'probability': 0.8416,
#       'type': 'Person',
#       'normalized_text': 'Karwa Chauth'}],
#     'mentions': [{'start': 3,
#       'end': 15,
#       'username': 'OpIndia_com',
#       'id': '74980737'}]},
#    'public_metrics': {'retweet_count': 615,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'created_at': '2021-10-26T00:42:53.000Z',
#    'possibly_sensitive': False,
#    'lang': 'en',
#    'author_id': '2791181612',
#    'text': 'RT @OpIndia_com: Dabur withdraws lesbian Karwa Chauth ad, apologises for hurting religious sentiments: Read their full statement\nhttps://t.…',
#    'id': '1452797847913390087',
#    'source': 'Twitter for Android'},
#   {'entities': {'annotations': [{'start': 13,
#       'end': 31,
#       'probability': 0.7591,
#       'type': 'Product',
#       'normalized_text': 'Grand Theft Auto IV'},
#      {'start': 45,
#       'end': 52,
#       'probability': 0.3848,
#       'type': 'Product',
#       'normalized_text': 'XBL Gold'}],
#     'hashtags': [{'start': 78, 'end': 81, 'tag': 'ad'}],
#     'mentions': [{'start': 3,
#       'end': 11,
#       'username': 'Wario64',
#       'id': '28955739'}],
#     'urls': [{'start': 54,
#       'end': 77,
#       'url': 'https://t.co/uWwFwbJRmG',
#       'expanded_url': 'https://bit.ly/3jAWwUr',
#       'display_url': 'bit.ly/3jAWwUr',
#       'unwound_url': 'https://click.linksynergy.com/link?id=0wLgH49VWzI&offerid=515462.11600593614&type=2&murl=https://www.xbox.com/en-us/games/store/Grand-Theft-Auto-IV/BRQ2SCZCTXF2'},
#      {'start': 82,
#       'end': 105,
#       'url': 'https://t.co/9ZlNzwQcnB',
#       'expanded_url': 'https://twitter.com/Wario64/status/1452791347304296453/photo/1',
#       'display_url': 'pic.twitter.com/9ZlNzwQcnB'}]},
#    'public_metrics': {'retweet_count': 25,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'created_at': '2021-10-26T00:42:53.000Z',
#    'possibly_sensitive': False,
#    'lang': 'en',
#    'author_id': '1129830841620652032',
#    'text': 'RT @Wario64: Grand Theft Auto IV is $6.99 on XBL Gold https://t.co/uWwFwbJRmG #ad https://t.co/9ZlNzwQcnB',
#    'id': '1452797847741468674',
#    'source': 'Twitter for iPhone'}],
#  'meta': {'newest_id': '1452797863126175750',
#   'oldest_id': '1452797847741468674',
#   'result_count': 10,
#   'next_token': 'b26v89c19zqg8o3fpdv6n040w83wgc2exadsaq46cfji5'}}

# %%
dict = json.dumps(r)

# %%
print(dict)
# Out:
# {"data": [{"entities": {"annotations": [{"start": 99, "end": 112, "probability": 0.5947, "type": "Organization", "normalized_text": "News Consumers"}], "hashtags": [{"start": 56, "end": 66, "tag": "Christmas"}], "mentions": [{"start": 3, "end": 19, "username": "goodbuysalltime", "id": "117271814"}]}, "public_metrics": {"retweet_count": 9, "reply_count": 0, "like_count": 0, "quote_count": 0}, "created_at": "2021-10-26T00:42:56.000Z", "possibly_sensitive": false, "lang": "en", "author_id": "2870146250", "text": "RT @goodbuysalltime: \ud83c\udf85It's Beginning to look a Lot like #Christmas \ud83c\udf84\nIf you've been watching the News Consumers are being advised to #ShopE\u2026", "id": "1452797863126175750", "source": "Twitter Web App"}, {"public_metrics": {"retweet_count": 778, "reply_count": 0, "like_count": 0, "quote_count": 0}, "created_at": "2021-10-26T00:42:56.000Z", "possibly_sensitive": false, "lang": "en", "author_id": "1262862854769631232", "text": "RT @jakeupdateteam: [DUCK AD TUTORIAL] \n\nLet's win a SUBWAY AD for #JAKE! \ud83d\udc36\ud83e\udde1\n\nGoal: 3,000,000 votes! \n\nDownload links: \n\ud83d\udd17https://t.co/caka7\u2026", "entities": {"hashtags": [{"start": 67, "end": 72, "tag": "JAKE"}], "mentions": [{"start": 3, "end": 18, "username": "jakeupdateteam", "id": "1283273218439229441"}]}, "id": "1452797863054827525", "source": "Twitter for Android"}, {"entities": {"annotations": [{"start": 13, "end": 20, "probability": 0.937, "type": "Organization", "normalized_text": "Facebook"}], "mentions": [{"start": 3, "end": 11, "username": "Reuters", "id": "1652541"}], "urls": [{"start": 81, "end": 104, "url": "https://t.co/D2XBJd1xpO", "expanded_url": "http://reut.rs/3CkpAqs", "display_url": "reut.rs/3CkpAqs", "images": [{"url": "https://pbs.twimg.com/news_img/1452797185964318720/zrnC03HD?format=jpg&name=orig", "width": 1200, "height": 628}, {"url": "https://pbs.twimg.com/news_img/1452797185964318720/zrnC03HD?format=jpg&name=150x150", "width": 150, "height": 150}], "status": 200, "title": "Facebook invests billions in metaverse efforts as ad business slows", "description": "Facebook Inc said on Monday it will start publishing the financial results of its augmented and virtual reality labs as a separate unit, where it is investing billions in its ambitions to build the \"metaverse\" and as it reported that its main advertising business faces \"significant uncertainty.\"", "unwound_url": "https://www.reuters.com/technology/facebook-revenue-misses-estimates-apples-privacy-rules-bite-2021-10-25/?taid=61774e610fbc4500016c9dc0&utm_campaign=trueAnthem:+Trending+Content&utm_medium=trueAnthem&utm_source=twitter"}, {"start": 105, "end": 128, "url": "https://t.co/wBsnFchX9B", "expanded_url": "https://twitter.com/Reuters/status/1452797184169086980/photo/1", "display_url": "pic.twitter.com/wBsnFchX9B"}]}, "public_metrics": {"retweet_count": 7, "reply_count": 0, "like_count": 0, "quote_count": 0}, "created_at": "2021-10-26T00:42:56.000Z", "possibly_sensitive": false, "lang": "en", "author_id": "734129690", "text": "RT @Reuters: Facebook invests billions in metaverse efforts as ad business slows https://t.co/D2XBJd1xpO https://t.co/wBsnFchX9B", "id": "1452797860156637187", "source": "Twitter for iPad"}, {"entities": {"annotations": [{"start": 18, "end": 35, "probability": 0.3564, "type": "Organization", "normalized_text": "NY Times Square ad"}, {"start": 42, "end": 45, "probability": 0.8013, "type": "Person", "normalized_text": "\u30b1\u30a4\u304f\u3093"}], "mentions": [{"start": 3, "end": 15, "username": "K_ILAND2020", "id": "1280648216845803521"}, {"start": 84, "end": 97, "username": "k_fluorite19", "id": "1300576927648854016"}]}, "public_metrics": {"retweet_count": 41, "reply_count": 0, "like_count": 0, "quote_count": 0}, "created_at": "2021-10-26T00:42:55.000Z", "possibly_sensitive": false, "lang": "ja", "author_id": "1177489707099246593", "text": "RT @K_ILAND2020: \u3010NY Times Square ad\u3011\n\nNY\u306e\u30b1\u30a4\u304f\u309 ...

# %%
data = json.loads(dict)
print(type(data))
print(data)
# Out:
# <class 'dict'>
# {'data': [{'entities': {'annotations': [{'start': 99, 'end': 112, 'probability': 0.5947, 'type': 'Organization', 'normalized_text': 'News Consumers'}], 'hashtags': [{'start': 56, 'end': 66, 'tag': 'Christmas'}], 'mentions': [{'start': 3, 'end': 19, 'username': 'goodbuysalltime', 'id': '117271814'}]}, 'public_metrics': {'retweet_count': 9, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'created_at': '2021-10-26T00:42:56.000Z', 'possibly_sensitive': False, 'lang': 'en', 'author_id': '2870146250', 'text': "RT @goodbuysalltime: 🎅It's Beginning to look a Lot like #Christmas 🎄\nIf you've been watching the News Consumers are being advised to #ShopE…", 'id': '1452797863126175750', 'source': 'Twitter Web App'}, {'public_metrics': {'retweet_count': 778, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'created_at': '2021-10-26T00:42:56.000Z', 'possibly_sensitive': False, 'lang': 'en', 'author_id': '1262862854769631232', 'text': "RT @jakeupdateteam: [DUCK AD TUTORIAL] \n\nLet's win a SUBWAY AD for #JAKE! 🐶🧡\n\nGoal: 3,000,000 votes! \n\nDownload links: \n🔗https://t.co/caka7…", 'entities': {'hashtags': [{'start': 67, 'end': 72, 'tag': 'JAKE'}], 'mentions': [{'start': 3, 'end': 18, 'username': 'jakeupdateteam', 'id': '1283273218439229441'}]}, 'id': '1452797863054827525', 'source': 'Twitter for Android'}, {'entities': {'annotations': [{'start': 13, 'end': 20, 'probability': 0.937, 'type': 'Organization', 'normalized_text': 'Facebook'}], 'mentions': [{'start': 3, 'end': 11, 'username': 'Reuters', 'id': '1652541'}], 'urls': [{'start': 81, 'end': 104, 'url': 'https://t.co/D2XBJd1xpO', 'expanded_url': 'http://reut.rs/3CkpAqs', 'display_url': 'reut.rs/3CkpAqs', 'images': [{'url': 'https://pbs.twimg.com/news_img/1452797185964318720/zrnC03HD?format=jpg&name=orig', 'width': 1200, 'height': 628}, {'url': 'https://pbs.twimg.com/news_img/1452797185964318720/zrnC03HD?format=jpg&name=150x150', 'width': 150, 'height': 150}], 'status': 200, 'title': 'Facebook invests billions in metaverse efforts as ad business slows', 'description': 'Facebook Inc said on Monday it will start publishing the financial results of its augmented and virtual reality labs as a separate unit, where it is investing billions in its ambitions to build the "metaverse" and as it reported that its main advertising business faces "significant uncertainty."', 'unwound_url': 'https://www.reuters.com/technology/facebook-revenue-misses-estimates-apples-privacy-rules-bite-2021-10-25/?taid=61774e610fbc4500016c9dc0&utm_campaign=trueAnthem:+Trending+Content&utm_medium=trueAnthem&utm_source=twitter'}, {'start': 105, 'end': 128, 'url': 'https://t.co/wBsnFchX9B', 'expanded_url': 'https://twitter.com/Reuters/status/1452797184169086980/photo/1', 'display_url': 'pic.twitter.com/wBsnFchX9B'}]}, 'public_metrics': {'retweet_count': 7, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'created_at': '2021-10-26T00:42:56.000Z', 'possibly_sensitive': False, 'lang': 'en', 'author_id': '734129690', 'text': 'RT @Reuters: Facebook invests billions in metaverse efforts as ad business slows https://t.co/D2XBJd1xpO https://t.co/wBsnFchX9B', 'id': '1452797860156637187', 'source': 'Twitter for iPad'}, {'entities': {'annotations': [{'start': 18, 'end': 35, 'probability': 0.3564, 'type': 'Organization', 'normalized_text': 'NY Times Square ad'}, {'start': 42, 'end': 45, 'probability': 0.8013, 'type': 'Person', 'normalized_text': 'ケイくん'}], 'mentions': [{'start': 3, 'end': 15, 'username': 'K_ILAND2020', 'id': '1280648216845803521'}, {'start': 84, 'end': 97, 'username': 'k_fluorite19', 'id': '1300576927648854016'}]}, 'public_metrics': {'retweet_count': 41, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'created_at': '2021-10-26T00:42:55.000Z', 'possibly_sensitive': False, 'lang': 'ja', 'author_id': '1177489707099246593', 'text': 'RT @K_ILAND2020: 【NY Times Square ad】\n\nNYのケイくんも本日最終日です🗽👏\n素敵な作品をNYへ届けることができて\n嬉しいですね✨\n@k_fluorite19 様ありがとうございました😊🙏\n\nデビューする日が待ち遠しいです🌙\n\n#HYBEJP…', 'id': '145279785826 ...

# %%
for tweet in data['data']:
    print(tweet)
# Out:
# {'entities': {'annotations': [{'start': 99, 'end': 112, 'probability': 0.5947, 'type': 'Organization', 'normalized_text': 'News Consumers'}], 'hashtags': [{'start': 56, 'end': 66, 'tag': 'Christmas'}], 'mentions': [{'start': 3, 'end': 19, 'username': 'goodbuysalltime', 'id': '117271814'}]}, 'public_metrics': {'retweet_count': 9, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'created_at': '2021-10-26T00:42:56.000Z', 'possibly_sensitive': False, 'lang': 'en', 'author_id': '2870146250', 'text': "RT @goodbuysalltime: 🎅It's Beginning to look a Lot like #Christmas 🎄\nIf you've been watching the News Consumers are being advised to #ShopE…", 'id': '1452797863126175750', 'source': 'Twitter Web App'}
# {'public_metrics': {'retweet_count': 778, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'created_at': '2021-10-26T00:42:56.000Z', 'possibly_sensitive': False, 'lang': 'en', 'author_id': '1262862854769631232', 'text': "RT @jakeupdateteam: [DUCK AD TUTORIAL] \n\nLet's win a SUBWAY AD for #JAKE! 🐶🧡\n\nGoal: 3,000,000 votes! \n\nDownload links: \n🔗https://t.co/caka7…", 'entities': {'hashtags': [{'start': 67, 'end': 72, 'tag': 'JAKE'}], 'mentions': [{'start': 3, 'end': 18, 'username': 'jakeupdateteam', 'id': '1283273218439229441'}]}, 'id': '1452797863054827525', 'source': 'Twitter for Android'}
# {'entities': {'annotations': [{'start': 13, 'end': 20, 'probability': 0.937, 'type': 'Organization', 'normalized_text': 'Facebook'}], 'mentions': [{'start': 3, 'end': 11, 'username': 'Reuters', 'id': '1652541'}], 'urls': [{'start': 81, 'end': 104, 'url': 'https://t.co/D2XBJd1xpO', 'expanded_url': 'http://reut.rs/3CkpAqs', 'display_url': 'reut.rs/3CkpAqs', 'images': [{'url': 'https://pbs.twimg.com/news_img/1452797185964318720/zrnC03HD?format=jpg&name=orig', 'width': 1200, 'height': 628}, {'url': 'https://pbs.twimg.com/news_img/1452797185964318720/zrnC03HD?format=jpg&name=150x150', 'width': 150, 'height': 150}], 'status': 200, 'title': 'Facebook invests billions in metaverse efforts as ad business slows', 'description': 'Facebook Inc said on Monday it will start publishing the financial results of its augmented and virtual reality labs as a separate unit, where it is investing billions in its ambitions to build the "metaverse" and as it reported that its main advertising business faces "significant uncertainty."', 'unwound_url': 'https://www.reuters.com/technology/facebook-revenue-misses-estimates-apples-privacy-rules-bite-2021-10-25/?taid=61774e610fbc4500016c9dc0&utm_campaign=trueAnthem:+Trending+Content&utm_medium=trueAnthem&utm_source=twitter'}, {'start': 105, 'end': 128, 'url': 'https://t.co/wBsnFchX9B', 'expanded_url': 'https://twitter.com/Reuters/status/1452797184169086980/photo/1', 'display_url': 'pic.twitter.com/wBsnFchX9B'}]}, 'public_metrics': {'retweet_count': 7, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'created_at': '2021-10-26T00:42:56.000Z', 'possibly_sensitive': False, 'lang': 'en', 'author_id': '734129690', 'text': 'RT @Reuters: Facebook invests billions in metaverse efforts as ad business slows https://t.co/D2XBJd1xpO https://t.co/wBsnFchX9B', 'id': '1452797860156637187', 'source': 'Twitter for iPad'}
# {'entities': {'annotations': [{'start': 18, 'end': 35, 'probability': 0.3564, 'type': 'Organization', 'normalized_text': 'NY Times Square ad'}, {'start': 42, 'end': 45, 'probability': 0.8013, 'type': 'Person', 'normalized_text': 'ケイくん'}], 'mentions': [{'start': 3, 'end': 15, 'username': 'K_ILAND2020', 'id': '1280648216845803521'}, {'start': 84, 'end': 97, 'username': 'k_fluorite19', 'id': '1300576927648854016'}]}, 'public_metrics': {'retweet_count': 41, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'created_at': '2021-10-26T00:42:55.000Z', 'possibly_sensitive': False, 'lang': 'ja', 'author_id': '1177489707099246593', 'text': 'RT @K_ILAND2020: 【NY Times Square ad】\n\nNYのケイくんも本日最終日です🗽👏\n素敵な作品をNYへ届けることができて\n嬉しいですね✨\n@k_fluorite19 様ありがとうございました😊🙏\n\nデビューする日が待ち遠しいです🌙\n\n#HYBEJP…', 'id': '1452797858269253641', 'source': 'Twitter for Android'}
# {'public_metrics': {'retweet_count': 964, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'created_at': '2021-10-26T00:42:55.000Z', 'possibly_sensitive': False, 'lang': 'en', 'author_id': '2785265579', 'text': 'RT @100trillionUSD: Dutch government is lying through their teeth to force vaccination without consent: denying natural immunity, and sayin…', 'id': '1452797857904402442', 'source': 'Twitter for iPhone', 'entities': {'mentions': [{'start': 3, 'end': 18, 'username': '100trillionUSD', 'id': '918804624303382528'}]}}
# {'public_metrics': {'retweet_count': 23, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'created_at': '2021-10-26T00:42:55.000Z', 'possibly_sensitive': False, 'lang': 'es', 'author_id': '1393169650389815297', 'text': 'RT @AquilianoL: @Mippcivzla Por el regreso a clases! 🙌✏️📒🧷\n#DigamosPresente\n@LCL23_1987 @LucenaCarmela @auritalucena @GorkiLucena @Elgrinc3…', 'entities': {'hashtags': [{'start': 59, 'end': 75, 'tag': 'DigamosPresente'}], 'mentions': [{'start': 3, 'end': 14, 'username': 'AquilianoL', 'id': '1379485239425257480'}, {'start': 16, 'end': 27, 'username': 'Mippcivzla', 'id': '839299289792774144'}, {'start': 76, 'end': 87, 'username': 'LCL23_1987', 'id': '267490254'}, {'start': 88, 'end': 102, 'username': 'LucenaCarmela', 'id': '1379574794358755328'}, {'start': 103, 'end': 116, 'username': 'auritalucena', 'id': '1390263017330429954'}, {'start': 117, 'end': 129, 'username': 'GorkiLucena', 'id': '1379748781416198145'}]}, 'id': '1452797856830607362', 'source': 'Twitter for Android'}
# {'public_metrics': {'retweet_count': 1, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'created_at': '2021-10-26T00:42:55.000Z', 'possibly_sensitive': False, 'lang': 'tr', 'author_id': '1238191063573159937', 'text': 'RT @McDrFn: Code 1KAZAMA #Ad https://t.co/pOJVuBu6PU', 'entities': {'hashtags': [{'start': 25, 'end': 28, 'tag': 'Ad'}], 'mentions': [{'start': 3, 'end': 10, 'username': 'McDrFn', 'id': '1449973818865373184'}], 'urls': [{'start': 29, 'end': 52, 'url': 'https://t.co/pOJVuBu6PU', 'expanded_url': 'https://twitter.com/McDrFn/status/1452797542350180361/photo/1', 'display_url': 'pic.twitter.com/pOJVuBu6PU'}]}, 'id': '1452797856088199170', 'source': 'Twitter for Android'}
# {'public_metrics': {'retweet_count': 579, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'created_at': '2021-10-26T00:42:54.000Z', 'possibly_sensitive': False, 'lang': 'en', 'author_id': '1285971193766371328', 'text': 'RT @PSHCITE: Since you’ll need to purchase gold coins to vote for #JAKE on whosfan, I’ll be proposing another donation drive for his birthd…', 'entities': {'hashtags': [{'start': 66, 'end': 71, 'tag': 'JAKE'}], 'mentions': [{'start': 3, 'end': 11, 'username': 'PSHCITE', 'id': '1323670537403392001'}]}, 'id': '1452797853420572677', 'source': 'Twitter for Android'}
# {'entities': {'annotations': [{'start': 41, 'end': 52, 'probability': 0.8416, 'type': 'Person', 'normalized_text': 'Karwa Chauth'}], 'mentions': [{'start': 3, 'end': 15, 'username': 'OpIndia_com', 'id': '74980737'}]}, 'public_metrics': {'retweet_count': 615, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'created_at': '2021-10-26T00:42:53.000Z', 'possibly_sensitive': False, 'lang': 'en', 'author_id': '2791181612', 'text': 'RT @OpIndia_com: Dabur withdraws lesbian Karwa Chauth ad, apologises for hurting religious sentiments: Read their full statement\nhttps://t.…', 'id': '1452797847913390087', 'source': 'Twitter for Android'}
# {'entities': {'annotations': [{'start': 13, 'end': 31, 'probability': 0.7591, 'type': 'Product', 'normalized_text': 'Grand Theft Auto IV'}, {'start': 45, 'end': 52, 'probability': 0.3848, 'type': 'Product', 'normalized_text': 'XBL Gold'}], 'hashtags': [{'start': 78, 'end': 81, 'tag': 'ad'}], 'mentions': [{'start': 3, 'end': 11, 'username': 'Wario64', 'id': '28955739'}], 'urls': [{'start': 54, 'end': 77, 'url': 'https://t.co/uWwFwbJRmG', 'expanded_url': 'https://bit.ly/3jAWwUr', 'display_url': 'bit.ly/3jAWwUr', 'unwound_url': 'https://click.linksynergy.com/link?id=0wLgH49VWzI&offerid=515462.11600593614&type=2&murl=https://www.xbox.com/en-us/games/store/Grand-Theft-Auto-IV/BRQ2SCZCTXF2'}, {'start': 82, 'end': 105, 'url': 'https://t.co/9ZlNzwQcnB', 'expanded_url': 'https://twitter.com/Wario64/status/1452791347304296453/photo/1', 'display_url': 'pic.twitter.com/9ZlNzwQcnB'}]}, 'public_metrics': {'retweet_count': 25, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'created_at': '2021-10-26T00:42:53.000Z', 'possibly_sensitive': False, 'lang': 'en', 'author_id': '1129830841620652032', 'text': 'RT @Wario64: Grand Theft Auto IV is $6.99 on XBL Gold https://t.co/uWwFwbJRmG #ad https://t.co/9ZlNzwQcnB', 'id': '1452797847741468674', 'source': 'Twitter for iPhone'}

# %%
test_df = pd.DataFrame(r['data'])
test_df.head()
# Out:
#                                             entities  \
# 0  {'annotations': [{'start': 99, 'end': 112, 'pr...
# 1  {'hashtags': [{'start': 67, 'end': 72, 'tag': ...
# 2  {'annotations': [{'start': 13, 'end': 20, 'pro...
# 3  {'annotations': [{'start': 18, 'end': 35, 'pro...
# 4  {'mentions': [{'start': 3, 'end': 18, 'usernam...
#
#                                       public_metrics  \
# 0  {'retweet_count': 9, 'reply_count': 0, 'like_c...
# 1  {'retweet_count': 778, 'reply_count': 0, 'like...
# 2  {'retweet_count': 7, 'reply_count': 0, 'like_c...
# 3  {'retweet_count': 41, 'reply_count': 0, 'like_...
# 4  {'retweet_count': 964, 'reply_count': 0, 'like...
#
#                  created_at  possibly_sensitive lang            author_id  \
# 0  2021-10-26T00:42:56.000Z               False   en           2870146250
# 1  2021-10-26T00:42:56.000Z               False   en  1262862854769631232
# 2  2021-10-26T00:42:56.000Z               False   en            734129690
# 3  2021-10-26T00:42:55.000Z               False   ja  1177489707099246593
# 4  2021-10-26T00:42:55.000Z               False   en           2785265579
#
#                                                 text                   id  \
# 0  RT @goodbuysalltime: 🎅It's Beginning to look a...  1452797863126175750
# 1  RT @jakeupdateteam: [DUCK AD TUTORIAL] \n\nLet...  1452797863054827525
# 2  RT @Reuters: Facebook invests billions in meta...  1452797860156637187
# 3  RT @K_ILAND2020: 【NY Times Square ad】\n\nNYのケイ...  1452797858269253641
# 4  RT @100trillionUSD: Dutch government is lying ...  1452797857904402442
#
#                 source
# 0      Twitter Web App
# 1  Twitter for Android
# 2     Twitter for iPad
# 3  Twitter for Android
# 4   Twitter for iPhone

# %%
entities_df = pd.json_normalize(test_df['entities'])
entities_df.head(3)
# Out:
#                                          annotations  \
# 0  [{'start': 99, 'end': 112, 'probability': 0.59...
# 1                                                NaN
# 2  [{'start': 13, 'end': 20, 'probability': 0.937...
#
#                                          hashtags  \
# 0  [{'start': 56, 'end': 66, 'tag': 'Christmas'}]
# 1       [{'start': 67, 'end': 72, 'tag': 'JAKE'}]
# 2                                             NaN
#
#                                             mentions  \
# 0  [{'start': 3, 'end': 19, 'username': 'goodbuys...
# 1  [{'start': 3, 'end': 18, 'username': 'jakeupda...
# 2  [{'start': 3, 'end': 11, 'username': 'Reuters'...
#
#                                                 urls
# 0                                                NaN
# 1                                                NaN
# 2  [{'start': 81, 'end': 104, 'url': 'https://t.c...

# %%
annotations_list = entities_df['hashtags'].tolist()
annotations_new = []
# annotations_list
# Out:
# [{'start': 56, 'end': 66, 'tag': 'Christmas'}]

# %%
public_metrics_df = pd.DataFrame(annotations_new)
public_metrics_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-b43bb60688dc> in <module>
# ----> 1 public_metrics_df = pd.DataFrame(annotations_new)
#       2 public_metrics_df
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     568                     if is_named_tuple(data[0]) and columns is None:
#     569                         columns = data[0]._fields
# --> 570                     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     571                     columns = ensure_index(columns)
#     572
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/pandas/core/internals/construction.py in to_arrays(data, columns, coerce_float, dtype)
#     526         return [], []  # columns if columns is not None else []
#     527     if isinstance(data[0], (list, tuple)):
# --> 528         return _list_to_arrays(data, columns, coerce_float=coerce_float, dtype=dtype)
#     529     elif isinstance(data[0], abc.Mapping):
#     530         return _list_of_dict_to_arrays(
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/pandas/core/internals/construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     563     else:
#     564         # list of lists
# --> 565         content = list(lib.to_object_array(data).T)
#     566     # gh-26429 do not raise user-facing AssertionError
#     567     try:
#
# pandas/_libs/lib.pyx in pandas._libs.lib.to_object_array()
#
# TypeError: object of type 'float' has no len()

# %%
public_metrics_df = pd.json_normalize(test_df['public_metrics'])
public_metrics_df.head()
# Out:
#    retweet_count  reply_count  like_count  quote_count
# 0              9            0           0            0
# 1            778            0           0            0
# 2              7            0           0            0
# 3             41            0           0            0
# 4            964            0           0            0
