# %% [markdown]
# Twitter Anaylsis - CSV Tables

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import matplotlib.dates as md
import datetime as dt
import pandas as pd
import scipy.stats as st
import numpy as np
import glob

# %%
csv_file_list = ['csv_output/Twitter_API_Table1.csv','csv_output/Twitter_API_Table2.csv']

list_of_dataframes = []
for filename in csv_file_list:
    list_of_dataframes.append(pd.read_csv(filename))

merged_df = pd.concat(list_of_dataframes)

merged_df
# Out:
#     Unnamed: 0                   id            author_id lang  \
# 0            0  1453472698349326338            197257623   en
# 1            1  1453472665193394189  1318432664496623616   en
# 2            2  1453472656682991617  1018893163925331968   en
# 3            3  1453472634319122433   705402063728017408   en
# 4            4  1453472610553974786           3889570332   en
# ..         ...                  ...                  ...  ...
# 81          95  1453475917800607744           4846392425   en
# 82          96  1453475885051482124           4846392425   en
# 83          97  1453475881486192643  1122250512902934528   en
# 84          98  1453475866957139969  1349702570739183618   en
# 85          99  1453475856186183681   741458105406365696   en
#
#                                                  text  \
# 0   RT @FortuneMagazine: MTN is making its network...
# 1   Amazon​.de: AMD Ryzen 9 5950X Box\n🔗 https://t...
# 2   RT @TeamSChandna: Watch #SurbhiChandna's new #...
# 3   Gardenrooms and sheds to read your books.. #ga...
# 4   RT @studiosounds: #Listen to Dayne S - Moments...
# ..                                                ...
# 81  RT @davelackie: I'm co-hosting the Beauty's Be...
# 82  RT @davelackie: Excited to be co-hosting the B...
# 83  RT @falcodrin: 🔥 BESTBUY : XFX Radeon RX 6600 ...
# 84  Apple 13" MacBook Air Silver | 1.6GHz i5 16GB ...
# 85  RT @allkpop: JEON SOMI's first debut studio al...
#
#                                                 title  \
# 0                                                 NaN
# 1                               AMD Ryzen 9 5950X Box
# 2                                                 NaN
# 3   Rowlinson Easy Fix Spiked Border Roll 1.8m - P...
# 4                             Moments - EP by Dayne S
# ..                                                ...
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
# 84                                                NaN
# 85                                                NaN
#
#                   created_at                      url               source  \
# 0   2021-10-27T21:24:30.000Z                      NaN  Twitter for Android
# 1   2021-10-27T21:24:22.000Z  https://t.co/q3rMN5ihRx              Twitter
# 2   2021-10-27T21:24:20.000Z                      NaN      Twitter Web App
# 3   2021-10-27T21:24:14.000Z  https://t.co/tur73NW2bY              Twitter
# 4   2021-10-27T21:24:09.000Z  https://t.co/NpunFEBHiR      Twitter Web App
# ..                       ...                      ...                  ...
# 81  2021-10-27T21:37:17.000Z                      NaN      Twitter Web App
# 82  2021-10-27T21:37:09.000Z                      NaN      Twitter Web App
# 83  2021-10-27T21:37:09.000Z  https://t.co/EHtgTkhpNI  Twitter for Android
# 84  2021-10-27T21:37:05.000Z  https://t.co/Z4TSHkiPG6              dlvr.it
# 85  2021-10-27T21:37:03.000Z                      NaN  Twitter for Android
#
#                             normalized_text  ...        tag 2          tag 3  \
# 0                                       MTN  ...          NaN            NaN
# 1                                       NaN  ...    partalert  pa_ryzen5950x
# 2                      Vitamin C Face Serum  ...           Ad    RoseAndGold
# 3                                       NaN  ...           ad           shed
# 4                                   Dayne S  ...        Dance             AD
# ..                                      ...  ...          ...            ...
# 81                                      NaN  ...          NaN            NaN
# 82                                      NaN  ...          NaN            NaN
# 83  XFX Radeon RX 6600 XT Speedster QICK308  ...          NaN            NaN
# 84                                 Apple 13  ...  refurbished          deals
# 85                                JEON SOMI  ...          NaN            NaN
#
#    tag 4 Mentions Total retweet count reply count  like count  quote count  \
# 0    NaN              1            18           0           0            0
# 1    NaN              0             0           0           0            0
# 2    NaN              2            29           0           0            0
# 3    NaN              0             0           0           0            0
# 4    NaN              1             1           0           0            0
# ..   ...            ...           ...         ...         ...          ...
# 81   NaN              1           213           0           0            0
# 82   NaN              1            68           0           0            0
# 83   NaN              1             1           0           0            0
# 84   NaN              0             0           0           0            0
# 85   NaN              1            53           0           0            0
#
#     possibly_sensitive  tag 5
# 0                 True    NaN
# 1                False    NaN
# 2                False    NaN
# 3                False    NaN
# 4                 True    NaN
# ..                 ...    ...
# 81               False    NaN
# 82               False    NaN
# 83               False    NaN
# 84               False    NaN
# 85               False    NaN
#
# [165 rows x 23 columns]

# %%
merged_total_df = merged_df.drop(['Unnamed: 0'], axis=1)
merged_total_df
# Out:
#                      id            author_id lang  \
# 0   1453472698349326338            197257623   en
# 1   1453472665193394189  1318432664496623616   en
# 2   1453472656682991617  1018893163925331968   en
# 3   1453472634319122433   705402063728017408   en
# 4   1453472610553974786           3889570332   en
# ..                  ...                  ...  ...
# 81  1453475917800607744           4846392425   en
# 82  1453475885051482124           4846392425   en
# 83  1453475881486192643  1122250512902934528   en
# 84  1453475866957139969  1349702570739183618   en
# 85  1453475856186183681   741458105406365696   en
#
#                                                  text  \
# 0   RT @FortuneMagazine: MTN is making its network...
# 1   Amazon​.de: AMD Ryzen 9 5950X Box\n🔗 https://t...
# 2   RT @TeamSChandna: Watch #SurbhiChandna's new #...
# 3   Gardenrooms and sheds to read your books.. #ga...
# 4   RT @studiosounds: #Listen to Dayne S - Moments...
# ..                                                ...
# 81  RT @davelackie: I'm co-hosting the Beauty's Be...
# 82  RT @davelackie: Excited to be co-hosting the B...
# 83  RT @falcodrin: 🔥 BESTBUY : XFX Radeon RX 6600 ...
# 84  Apple 13" MacBook Air Silver | 1.6GHz i5 16GB ...
# 85  RT @allkpop: JEON SOMI's first debut studio al...
#
#                                                 title  \
# 0                                                 NaN
# 1                               AMD Ryzen 9 5950X Box
# 2                                                 NaN
# 3   Rowlinson Easy Fix Spiked Border Roll 1.8m - P...
# 4                             Moments - EP by Dayne S
# ..                                                ...
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
# 84                                                NaN
# 85                                                NaN
#
#                   created_at                      url               source  \
# 0   2021-10-27T21:24:30.000Z                      NaN  Twitter for Android
# 1   2021-10-27T21:24:22.000Z  https://t.co/q3rMN5ihRx              Twitter
# 2   2021-10-27T21:24:20.000Z                      NaN      Twitter Web App
# 3   2021-10-27T21:24:14.000Z  https://t.co/tur73NW2bY              Twitter
# 4   2021-10-27T21:24:09.000Z  https://t.co/NpunFEBHiR      Twitter Web App
# ..                       ...                      ...                  ...
# 81  2021-10-27T21:37:17.000Z                      NaN      Twitter Web App
# 82  2021-10-27T21:37:09.000Z                      NaN      Twitter Web App
# 83  2021-10-27T21:37:09.000Z  https://t.co/EHtgTkhpNI  Twitter for Android
# 84  2021-10-27T21:37:05.000Z  https://t.co/Z4TSHkiPG6              dlvr.it
# 85  2021-10-27T21:37:03.000Z                      NaN  Twitter for Android
#
#                             normalized_text          type  ...        tag 2  \
# 0                                       MTN  Organization  ...          NaN
# 1                                       NaN           NaN  ...    partalert
# 2                      Vitamin C Face Serum       Product  ...           Ad
# 3                                       NaN           NaN  ...           ad
# 4                                   Dayne S        Person  ...        Dance
# ..                                      ...           ...  ...          ...
# 81                                      NaN           NaN  ...          NaN
# 82                                      NaN           NaN  ...          NaN
# 83  XFX Radeon RX 6600 XT Speedster QICK308       Product  ...          NaN
# 84                                 Apple 13       Product  ...  refurbished
# 85                                JEON SOMI        Person  ...          NaN
#
#             tag 3 tag 4 Mentions Total retweet count  reply count  like count  \
# 0             NaN   NaN              1            18            0           0
# 1   pa_ryzen5950x   NaN              0             0            0           0
# 2     RoseAndGold   NaN              2            29            0           0
# 3            shed   NaN              0             0            0           0
# 4              AD   NaN              1             1            0           0
# ..            ...   ...            ...           ...          ...         ...
# 81            NaN   NaN              1           213            0           0
# 82            NaN   NaN              1            68            0           0
# 83            NaN   NaN              1             1            0           0
# 84          deals   NaN              0             0            0           0
# 85            NaN   NaN              1            53            0           0
#
#     quote count  possibly_sensitive  tag 5
# 0             0                True    NaN
# 1             0               False    NaN
# 2             0               False    NaN
# 3             0               False    NaN
# 4             0                True    NaN
# ..          ...                 ...    ...
# 81            0               False    NaN
# 82            0               False    NaN
# 83            0               False    NaN
# 84            0               False    NaN
# 85            0               False    NaN
#
# [165 rows x 22 columns]

# %%
merged_total_df.to_csv('csv_output/Twitter_API_Merged_Table.csv')

# %% [markdown]
# Time Vs. Retweets

# %%
df_created=merged_total_df['created_at'].apply(pd.Series)
df_created
# Out:
#                            0
# 0   2021-10-27T21:24:30.000Z
# 1   2021-10-27T21:24:22.000Z
# 2   2021-10-27T21:24:20.000Z
# 3   2021-10-27T21:24:14.000Z
# 4   2021-10-27T21:24:09.000Z
# ..                       ...
# 81  2021-10-27T21:37:17.000Z
# 82  2021-10-27T21:37:09.000Z
# 83  2021-10-27T21:37:09.000Z
# 84  2021-10-27T21:37:05.000Z
# 85  2021-10-27T21:37:03.000Z
#
# [165 rows x 1 columns]

# %%
df_created2= df_created[0].str.split("T", n = -1, expand = True)
df_created2
# Out:
#              0              1
# 0   2021-10-27  21:24:30.000Z
# 1   2021-10-27  21:24:22.000Z
# 2   2021-10-27  21:24:20.000Z
# 3   2021-10-27  21:24:14.000Z
# 4   2021-10-27  21:24:09.000Z
# ..         ...            ...
# 81  2021-10-27  21:37:17.000Z
# 82  2021-10-27  21:37:09.000Z
# 83  2021-10-27  21:37:09.000Z
# 84  2021-10-27  21:37:05.000Z
# 85  2021-10-27  21:37:03.000Z
#
# [165 rows x 2 columns]

# %%
df_created2["date"]=df_created2[0]
df_created2["time"]=df_created2[1]
df_created2.drop(columns=[0,1], inplace = True)
df_created2
# Out:
#           date           time
# 0   2021-10-27  21:24:30.000Z
# 1   2021-10-27  21:24:22.000Z
# 2   2021-10-27  21:24:20.000Z
# 3   2021-10-27  21:24:14.000Z
# 4   2021-10-27  21:24:09.000Z
# ..         ...            ...
# 81  2021-10-27  21:37:17.000Z
# 82  2021-10-27  21:37:09.000Z
# 83  2021-10-27  21:37:09.000Z
# 84  2021-10-27  21:37:05.000Z
# 85  2021-10-27  21:37:03.000Z
#
# [165 rows x 2 columns]

# %%
df_created2['retweet count'] = merged_total_df['retweet count'].values
df_created2
# Out:
#           date           time  retweet count
# 0   2021-10-27  21:24:30.000Z             18
# 1   2021-10-27  21:24:22.000Z              0
# 2   2021-10-27  21:24:20.000Z             29
# 3   2021-10-27  21:24:14.000Z              0
# 4   2021-10-27  21:24:09.000Z              1
# ..         ...            ...            ...
# 81  2021-10-27  21:37:17.000Z            213
# 82  2021-10-27  21:37:09.000Z             68
# 83  2021-10-27  21:37:09.000Z              1
# 84  2021-10-27  21:37:05.000Z              0
# 85  2021-10-27  21:37:03.000Z             53
#
# [165 rows x 3 columns]

# %%
df_sort= df_created2.sort_values(by=["time"], ascending=False)
df_sort
# Out:
#           date           time  retweet count
# 0   2021-10-27  21:42:28.000Z            177
# 1   2021-10-27  21:42:28.000Z              2
# 2   2021-10-27  21:42:26.000Z              0
# 3   2021-10-27  21:42:22.000Z              0
# 4   2021-10-27  21:42:01.000Z            177
# ..         ...            ...            ...
# 73  2021-10-27  21:21:37.000Z              0
# 75  2021-10-27  21:21:33.000Z             86
# 76  2021-10-27  21:21:32.000Z              7
# 77  2021-10-27  21:21:30.000Z              1
# 78  2021-10-27  21:21:29.000Z              2
#
# [165 rows x 3 columns]

# %%
df_sort2 = df_sort.iloc[::9, :]
df_sort3 = df_sort2.sort_values(by=["time"], ascending=True)
df_sort3
# Out:
#           date           time  retweet count
# 76  2021-10-27  21:21:32.000Z              7
# 67  2021-10-27  21:21:53.000Z            167
# 59  2021-10-27  21:22:18.000Z              0
# 49  2021-10-27  21:22:46.000Z              0
# 40  2021-10-27  21:23:03.000Z              0
# 31  2021-10-27  21:23:19.000Z              0
# 22  2021-10-27  21:23:37.000Z              0
# 13  2021-10-27  21:23:47.000Z            167
# 4   2021-10-27  21:24:09.000Z              1
# 81  2021-10-27  21:37:17.000Z            213
# 72  2021-10-27  21:37:59.000Z              1
# 62  2021-10-27  21:38:42.000Z              0
# 54  2021-10-27  21:39:32.000Z            177
# 45  2021-10-27  21:40:01.000Z             70
# 36  2021-10-27  21:40:24.000Z            125
# 27  2021-10-27  21:41:04.000Z             24
# 18  2021-10-27  21:41:24.000Z              0
# 9   2021-10-27  21:41:50.000Z             91
# 0   2021-10-27  21:42:28.000Z            177

# %%
fig=plt.figure(figsize=(15,15))
plt.scatter(df_sort3['time'], df_sort3["retweet count"])
plt.title("Time vs. Retweets in a sertain time frame for 1 day", fontsize=16)
plt.xlabel("Time od Ad published on Twitter", fontsize=13)
plt.ylabel("Retweets", fontsize=13)
#plt.ylim(0,200)
plt.xticks(rotation=75)
plt.savefig("API_images/Timevs.Retweets_final.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Time vs. Source
source_count = merged_total_df["source"].unique()
source_count
# Out:
# array(['Twitter for Android', 'Twitter', 'Twitter Web App',
#        'Twitter for iPhone', 'Twitter for iPad', 'Tweetlogix', 'Stonky69',
#        'Buffer', 'comichaveli', 'RT #MachineLearning', 'Lewie',
#        'Twitter Media Studio', 'TweetDeck', 'Sprinklr', 'Hootsuite Inc.',
#        'dlvr.it'], dtype=object)

# %%
source_count2=merged_total_df["source"].value_counts()
source_count2
# Out:
# Twitter Web App         42
# Twitter                 36
# Twitter for Android     36
# Twitter for iPhone      27
# Stonky69                 8
# TweetDeck                5
# Twitter for iPad         2
# Sprinklr                 1
# Buffer                   1
# Lewie                    1
# comichaveli              1
# Tweetlogix               1
# dlvr.it                  1
# Twitter Media Studio     1
# RT #MachineLearning      1
# Hootsuite Inc.           1
# Name: source, dtype: int64

# %%
source_count2.plot(kind="bar", figsize=(10,10), color = "b",legend=True)
plt.ylabel("Usage Count")
plt.xlabel("Source Utilized")
plt.title("Frequency of Source Ultilization for Accessing Twitter")
plt.savefig('Frequency of Source Ultilization for Accessing Twitter')
plt.show()

print("The most frequently utilized source is the Twitter Web App.")
# Out:
# The most frequently utilized source is the Twitter Web App.

# %%
#mentions_total vs. retweets correlation 
#number of hashtag/mention totals have correlation to retweets/engagement levels? 

mentions_df=merged_total_df['Mentions Total'].apply(pd.Series)
mentions_df
# Out:
#     0
# 0   1
# 1   0
# 2   2
# 3   0
# 4   1
# .. ..
# 81  1
# 82  1
# 83  1
# 84  0
# 85  1
#
# [165 rows x 1 columns]

# %%
# Convert the column name into "Mention Total"
mentions_df = mentions_df.rename(
    columns={"": "Mentions Total"})
mentions_df
# Out:
#     0
# 0   1
# 1   0
# 2   2
# 3   0
# 4   1
# .. ..
# 81  1
# 82  1
# 83  1
# 84  0
# 85  1
#
# [165 rows x 1 columns]

# %%
mentions['retweet count'] = merged_total_df['retweet count'].values
mentions
# Out:
#     0  retweet count
# 0   1             18
# 1   0              0
# 2   2             29
# 3   0              0
# 4   1              1
# .. ..            ...
# 81  1            213
# 82  1             68
# 83  1              1
# 84  0              0
# 85  1             53
#
# [165 rows x 2 columns]

# %%
#set-up line chart to show how many instances mentions potentially influenced retweets and vice versa 

mentions.plot(kind="line", figsize=(25, 25), color = "b", legend=True)
plt.ylabel("Mentions Total")
plt.xlabel("Retweet Count")
plt.title("Mentions Total vs. Retweet Counts")
plt.savefig("Mentions Total Vs. Retweet Counts Line.png")
