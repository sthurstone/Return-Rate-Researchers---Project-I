# %% [markdown]
# Twitter Anaylsis - CSV Tables

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import glob

# %%
#data files
#Twitter_API_Table = "csv_output/Twitter_API_Table1.csv"
#Twitter_API_Table2 = "csv_output/Twitter_API_Table2.csv"

#read files
#Twitter_API_Table  = pd.read_csv(Twitter_API_Table)
#Twitter_API_Table2 = pd.read_csv(Twitter_API_Table2)

#Add blank column to merge data
#Twitter_API_Table["Column"] = ""
#Twitter_API_Table2 ["Column"] = ""

# %%
csv_file_list = ['csv_output/Twitter_API_Table1.csv','csv_output/Twitter_API_Table2.csv']

list_of_dataframes = []
for filename in csv_file_list:
    list_of_dataframes.append(pd.read_csv(filename))

merged_df = pd.concat(list_of_dataframes)

merged_df.head()
# Out:
#    Unnamed: 0                   id            author_id lang  \
# 0           0  1453472698349326338            197257623   en
# 1           1  1453472665193394189  1318432664496623616   en
# 2           2  1453472656682991617  1018893163925331968   en
# 3           3  1453472634319122433   705402063728017408   en
# 4           4  1453472610553974786           3889570332   en
#
#                                                 text  \
# 0  RT @FortuneMagazine: MTN is making its network...
# 1  Amazon​.de: AMD Ryzen 9 5950X Box\n🔗 https://t...
# 2  RT @TeamSChandna: Watch #SurbhiChandna's new #...
# 3  Gardenrooms and sheds to read your books.. #ga...
# 4  RT @studiosounds: #Listen to Dayne S - Moments...
#
#                                                title  \
# 0                                                NaN
# 1                              AMD Ryzen 9 5950X Box
# 2                                                NaN
# 3  Rowlinson Easy Fix Spiked Border Roll 1.8m - P...
# 4                            Moments - EP by Dayne S
#
#                  created_at                      url               source  \
# 0  2021-10-27T21:24:30.000Z                      NaN  Twitter for Android
# 1  2021-10-27T21:24:22.000Z  https://t.co/q3rMN5ihRx              Twitter
# 2  2021-10-27T21:24:20.000Z                      NaN      Twitter Web App
# 3  2021-10-27T21:24:14.000Z  https://t.co/tur73NW2bY              Twitter
# 4  2021-10-27T21:24:09.000Z  https://t.co/NpunFEBHiR      Twitter Web App
#
#         normalized_text  ...      tag 2          tag 3 tag 4 Mentions Total  \
# 0                   MTN  ...        NaN            NaN   NaN              1
# 1                   NaN  ...  partalert  pa_ryzen5950x   NaN              0
# 2  Vitamin C Face Serum  ...         Ad    RoseAndGold   NaN              2
# 3                   NaN  ...         ad           shed   NaN              0
# 4               Dayne S  ...      Dance             AD   NaN              1
#
#   retweet count reply count  like count  quote count  possibly_sensitive  \
# 0            18           0           0            0                True
# 1             0           0           0            0               False
# 2            29           0           0            0               False
# 3             0           0           0            0               False
# 4             1           0           0            0                True
#
#    tag 5
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
#
# [5 rows x 23 columns]

# %%
merged_total_df = merged_df.drop(['Unnamed: 0'], axis=1)
merged_total_df
# Out:
#                      id            author_id lang  \
# 0   1453472698349326338            197257623   en
# 1   1453472665193394189  1318432664496623616   en
# 2   1453472656682991617  1018893163925331968   en
# 3   1453472634319122433   705402063728017408   en
# 4   1453472610553974786           3889570332   en
# ..                  ...                  ...  ...
# 81  1453475917800607744           4846392425   en
# 82  1453475885051482124           4846392425   en
# 83  1453475881486192643  1122250512902934528   en
# 84  1453475866957139969  1349702570739183618   en
# 85  1453475856186183681   741458105406365696   en
#
#                                                  text  \
# 0   RT @FortuneMagazine: MTN is making its network...
# 1   Amazon​.de: AMD Ryzen 9 5950X Box\n🔗 https://t...
# 2   RT @TeamSChandna: Watch #SurbhiChandna's new #...
# 3   Gardenrooms and sheds to read your books.. #ga...
# 4   RT @studiosounds: #Listen to Dayne S - Moments...
# ..                                                ...
# 81  RT @davelackie: I'm co-hosting the Beauty's Be...
# 82  RT @davelackie: Excited to be co-hosting the B...
# 83  RT @falcodrin: 🔥 BESTBUY : XFX Radeon RX 6600 ...
# 84  Apple 13" MacBook Air Silver | 1.6GHz i5 16GB ...
# 85  RT @allkpop: JEON SOMI's first debut studio al...
#
#                                                 title  \
# 0                                                 NaN
# 1                               AMD Ryzen 9 5950X Box
# 2                                                 NaN
# 3   Rowlinson Easy Fix Spiked Border Roll 1.8m - P...
# 4                             Moments - EP by Dayne S
# ..                                                ...
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
# 84                                                NaN
# 85                                                NaN
#
#                   created_at                      url               source  \
# 0   2021-10-27T21:24:30.000Z                      NaN  Twitter for Android
# 1   2021-10-27T21:24:22.000Z  https://t.co/q3rMN5ihRx              Twitter
# 2   2021-10-27T21:24:20.000Z                      NaN      Twitter Web App
# 3   2021-10-27T21:24:14.000Z  https://t.co/tur73NW2bY              Twitter
# 4   2021-10-27T21:24:09.000Z  https://t.co/NpunFEBHiR      Twitter Web App
# ..                       ...                      ...                  ...
# 81  2021-10-27T21:37:17.000Z                      NaN      Twitter Web App
# 82  2021-10-27T21:37:09.000Z                      NaN      Twitter Web App
# 83  2021-10-27T21:37:09.000Z  https://t.co/EHtgTkhpNI  Twitter for Android
# 84  2021-10-27T21:37:05.000Z  https://t.co/Z4TSHkiPG6              dlvr.it
# 85  2021-10-27T21:37:03.000Z                      NaN  Twitter for Android
#
#                             normalized_text          type  ...        tag 2  \
# 0                                       MTN  Organization  ...          NaN
# 1                                       NaN           NaN  ...    partalert
# 2                      Vitamin C Face Serum       Product  ...           Ad
# 3                                       NaN           NaN  ...           ad
# 4                                   Dayne S        Person  ...        Dance
# ..                                      ...           ...  ...          ...
# 81                                      NaN           NaN  ...          NaN
# 82                                      NaN           NaN  ...          NaN
# 83  XFX Radeon RX 6600 XT Speedster QICK308       Product  ...          NaN
# 84                                 Apple 13       Product  ...  refurbished
# 85                                JEON SOMI        Person  ...          NaN
#
#             tag 3 tag 4 Mentions Total retweet count  reply count  like count  \
# 0             NaN   NaN              1            18            0           0
# 1   pa_ryzen5950x   NaN              0             0            0           0
# 2     RoseAndGold   NaN              2            29            0           0
# 3            shed   NaN              0             0            0           0
# 4              AD   NaN              1             1            0           0
# ..            ...   ...            ...           ...          ...         ...
# 81            NaN   NaN              1           213            0           0
# 82            NaN   NaN              1            68            0           0
# 83            NaN   NaN              1             1            0           0
# 84          deals   NaN              0             0            0           0
# 85            NaN   NaN              1            53            0           0
#
#     quote count  possibly_sensitive  tag 5
# 0             0                True    NaN
# 1             0               False    NaN
# 2             0               False    NaN
# 3             0               False    NaN
# 4             0                True    NaN
# ..          ...                 ...    ...
# 81            0               False    NaN
# 82            0               False    NaN
# 83            0               False    NaN
# 84            0               False    NaN
# 85            0               False    NaN
#
# [165 rows x 22 columns]

# %%
# mini df
mini_tags = merged_total_df[['tag 1', 'tag 2', 'tag 3', 'tag 4', 'tag 5']]

# count number of tags per tweet
mini_tags['tag counts'] = mini_tags.count(axis =1)

# merge with retweets and likes
retweets_df = merged_total_df['retweet count']
likes_df = merged_total_df['like count']

# graph number of tags against retweets and likes
mini_merged.head()
# Out:
# /var/folders/6j/g7z_h15n2xb6lf5plnw73lrm0000gn/T/ipykernel_54173/2921102251.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mini_tags['tag counts'] = mini_tags.count(axis =1)
# /var/folders/6j/g7z_h15n2xb6lf5plnw73lrm0000gn/T/ipykernel_54173/2921102251.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   retweets_df['fake'] = merged_total_df['id']
#   tag 1      tag 2          tag 3 tag 4 tag 5  tag counts  retweet count
# 0    ad        NaN            NaN   NaN   NaN           1             18
# 0    ad        NaN            NaN   NaN   NaN           1            177
# 0    ad        NaN            NaN   NaN   NaN           1             18
# 0    ad        NaN            NaN   NaN   NaN           1            177
# 1    ad  partalert  pa_ryzen5950x   NaN   NaN           3              0

# %%
merged_total_df.to_csv('csv_output/Twitter_API_Merged_Table.csv')
