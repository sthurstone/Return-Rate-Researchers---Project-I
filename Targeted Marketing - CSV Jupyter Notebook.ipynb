# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
Facebook_Ads = "Facebook_Ads_2.csv"
KAG_Conversions= "KAG_conversion_data.csv"
Social_Network_Ads="Social_Network_Ads(1).csv"
Social_Influence="social-influence-on-shopping.csv"

# Read the mouse data and the study results
Facebook_Ads = pd.read_csv(Facebook_Ads)
KAG_Conversions = pd.read_csv(KAG_Conversions)
Social_Network_Ads=pd.read_csv(Social_Network_Ads)
Social_Influence=pd.read_csv(Social_Influence)


Facebook_Ads["Column"] = ""
KAG_Conversions["Column"] = ""
Social_Network_Ads["Column"] = ""
Social_Influence["Column"]=""

# %%
Facebook_Ads.head(10)
# Out:
#              Names  Time Spent on Site      Salary   Clicked Column
# 0    Martina Avila           25.649648  $55,330.06         0
# 1    Harlan Barnes           32.456107  $79,049.08         1
# 2  Naomi Rodriquez           20.945978  $41,098.61         0
# 3  Jade Cunningham           54.039325  $37,143.36         1
# 4     Cedric Leach           34.249729  $37,355.11         0
# 5     Carla Hester           52.009946  $80,642.65         1
# 6   Griffin Rivera           42.881370  $61,908.40         1
# 7       Orli Casey           25.676920  $29,851.41         0
# 8     Marny Obrien           40.698233  $34,281.12         1
# 9    Rhonda Chavez           29.687362  $41,098.88         0

# %%
KAG_Conversions.head(10)
# Out:
#     ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0  708746              916          103916  30-34      M        15
# 1  708749              916          103917  30-34      M        16
# 2  708771              916          103920  30-34      M        20
# 3  708815              916          103928  30-34      M        28
# 4  708818              916          103928  30-34      M        28
# 5  708820              916          103929  30-34      M        29
# 6  708889              916          103940  30-34      M        15
# 7  708895              916          103941  30-34      M        16
# 8  708953              916          103951  30-34      M        27
# 9  708958              916          103952  30-34      M        28
#
#    Impressions  Clicks  Spent  Total_Conversion  Approved_Conversion Column
# 0         7350       1   1.43                 2                    1
# 1        17861       2   1.82                 2                    0
# ...

# %%
Social_Network_Ads.head(10)
# Out:
#     User ID  gender  Age  EstimatedSalary   Purchased Column
# 0  15624510    Male   19       $19,000.00           0
# 1  15810944    Male   35       $20,000.00           0
# 2  15668575  Female   26       $43,000.00           0
# 3  15603246  Female   27       $57,000.00           0
# 4  15804002    Male   19       $76,000.00           0
# 5  15728773    Male   27       $58,000.00           0
# 6  15598044  Female   27       $84,000.00           0
# 7  15694829  Female   32      $150,000.00           1
# 8  15600575    Male   25       $33,000.00           0
# 9  15727311  Female   35       $65,000.00           0

# %%
Social_Influence.head(10)
# Out:
#                                             Question Segment Type  \
# 0  What social platform has influenced your onlin...       Mobile
# 1  What social platform has influenced your onlin...       Mobile
# 2  What social platform has influenced your onlin...       Mobile
# 3  What social platform has influenced your onlin...       Mobile
# 4  What social platform has influenced your onlin...       Mobile
# 5  What social platform has influenced your onlin...          Web
# 6  What social platform has influenced your onlin...          Web
# 7  What social platform has influenced your onlin...          Web
# 8  What social platform has influenced your onlin...          Web
# 9  What social platform has influenced your onlin...          Web
#
#   Segment Description     Answer  Count  Percentage Column
# 0      Global results   Facebook    548       0.205
# 1      Global results  Instagram    916       0.342
# 2      Global results   Snapchat     86       0.032
# ...

# %%
#Merge Data

combined_data1=pd.merge(KAG_Conversions, Social_Network_Ads, how='right', on="Column")

# Display the data table for preview

combined_data1.head(10)
# Out:
#     ad_id  xyz_campaign_id  fb_campaign_id    age gender_x  interest  \
# 0  708746              916          103916  30-34        M        15
# 1  708749              916          103917  30-34        M        16
# 2  708771              916          103920  30-34        M        20
# 3  708815              916          103928  30-34        M        28
# 4  708818              916          103928  30-34        M        28
# 5  708820              916          103929  30-34        M        29
# 6  708889              916          103940  30-34        M        15
# 7  708895              916          103941  30-34        M        16
# 8  708953              916          103951  30-34        M        27
# 9  708958              916          103952  30-34        M        28
#
#    Impressions  Clicks  Spent  Total_Conversion  Approved_Conversion Column  \
# 0         7350       1   1.43                 2                    1
# ...

# %%
#Merge Data Continuted

#need to add filler columns and merge data sets on them

combined_data2=pd.merge(combined_data1,Facebook_Ads, how='right', on="Column")

# Display data set as preview 

combined_data2.head(10)

# %%
#Merge Data Continuted

combined_complete=pd.merge(combined_data1,Social_Influence, how='right', on="Column")

# Display data set as preview 

combined_complete.head(10)
